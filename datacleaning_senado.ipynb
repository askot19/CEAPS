# %% [markdown]
# # Relatório de Análises
# O seguinte projeto visa obter dados da transparência governamental, focados nos últimos quatro anos do Senado brasileiro (CEAP - Cota para Exercício da Atividade Parlamentar). O objetivo deste projeto é praticar as principais ferramentas envolvendo Ciência de Dados e produzir um relatório completo através da linguagem de programação Python, do programa de DataViz Power BI e aplicar conceitos introdutórios de Machine Learning.
#
# A ideia por trás é simular a Operação Serenata de Amor, que utilizou-se do algoritmo Rosie, uma inteligência artificial capaz de analisar os gastos reembolsados pela CEAP, de deputados federais e senadores, feitos em exercício de sua função, identificando suspeitas e incentivando a população a questioná-los.

# %%
# Importando pacotes de Análise de Dados

import pandas as pd
import numpy as np

# %%
# Importação de dados

url = 'https://www.senado.gov.br/transparencia/LAI/verba/despesa_ceaps_'

# Aqui estamos agrupando as planilhas de 2010 a 2023, através do método concat e codificando a leitura do arquivo para facilitar a manipulação dos dados
dados_ceaps = pd.concat(pd.read_csv(url+str(ano)+'.csv', encoding='ISO-8859-1', sep=';', skiprows=1) for ano in range(2010,2023))
dados_ceaps.reset_index(drop=True, inplace=True) # Nessa linha corrigimos o índice com o método reset_index

# %%
# Visualização dos dados
dados_ceaps.head(10)
# Out:
#     ANO  MES       SENADOR                                       TIPO_DESPESA  \
# 0  2010    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 1  2010    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 2  2010    1  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 3  2010    1  ACIR GURGACZ                Divulgação da atividade parlamentar
# 4  2010    1  ACIR GURGACZ  Locomoção, hospedagem, alimentação, combustíve...
# 5  2010    1  ACIR GURGACZ  Locomoção, hospedagem, alimentação, combustíve...
# 6  2010    1  ACIR GURGACZ  Locomoção, hospedagem, alimentação, combustíve...
# 7  2010    1  ACIR GURGACZ  Locomoção, hospedagem, alimentação, combustíve...
# 8  2010    2  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
# 9  2010    2  ACIR GURGACZ  Aluguel de imóveis para escritório político, c...
#
#              CNPJ_CPF                              FORNECEDOR  DOCUMENTO  \
# 0  05.914.650/0001-66          CENTRAIS ELÉTRICAS DE RONDÔNIA   045216-3
# 1  05.914.650/0001-66          CENTRAIS ELÉTRICAS DE RONDônia  0454206-1
# 2      004.948.028-63           GILBERTO PISELO DO NASCIMENTO        NaN
# 3  09.040.457/0001-02                    CENTRAL RONDÔNIA.COM     000003
# 4  15.896.509/0001-31                         POSTO FORTALEZA     018215
# 5  15.896.509/0001-31                         POSTO FORTALEZA     018884
# 6  63.755.391/0001-74                  VICENTE & TESTONI LTDA     050501
# 7  63.755.391/0001-74                  vicente & testoni ltda     050201
# 8  05.914.650/0001-66  CENTRAIS ELÉTRICAS DE RONDÔNIA - CERON  0452163-3
# 9  05.914.650/0001-66  CENTRAIS ELÉTRICAS DE RONDÔNIA - CERON  0454206-1
#
#          DATA DETALHAMENTO VALOR_REEMBOLSADO  COD_DOCUMENTO
# 0  19/01/2010          NaN             59,08       277219.0
# 1  19/01/2010          NaN             40,47       277218.0
# 2  12/01/2010          NaN              5000       229109.0
# 3  05/01/2010          NaN              1500       268264.0
# 4  07/01/2010          NaN                30       268265.0
# 5  27/01/2010          NaN               111       268266.0
# 6  07/01/2010          NaN               100       268268.0
# 7  02/01/2010          NaN                50       268267.0
# 8  19/02/2010          NaN             40,27       277223.0
# 9  19/02/2010          NaN             69,27       277222.0

# %%
# Conferindo tipos de dados
dados_ceaps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298978 entries, 0 to 298977
# Data columns (total 11 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ANO                298978 non-null  int64
#  1   MES                298978 non-null  int64
#  2   SENADOR            298978 non-null  object
#  3   TIPO_DESPESA       298978 non-null  object
#  4   CNPJ_CPF           298978 non-null  object
#  5   FORNECEDOR         298978 non-null  object
#  6   DOCUMENTO          278752 non-null  object
#  7   DATA               298978 non-null  object
#  8   DETALHAMENTO       180631 non-null  object
#  9   VALOR_REEMBOLSADO  298978 non-null  object
#  10  COD_DOCUMENTO      298976 non-null  float64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.1+ MB

# %%
# Verificando coerência dos dados do final do Data Frame
dados_ceaps.tail()
# Out:
#          ANO  MES           SENADOR  \
# 298973  2022   12  ZEQUINHA MARINHO
# 298974  2022   12  ZEQUINHA MARINHO
# 298975  2022   12  ZEQUINHA MARINHO
# 298976  2022   12  ZEQUINHA MARINHO
# 298977  2022   12  ZEQUINHA MARINHO
#
#                                              TIPO_DESPESA            CNPJ_CPF  \
# 298973  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 298974  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 298975  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 298976  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
# 298977  Passagens aéreas, aquáticas e terrestres nacio...  22.052.777/0001-32
#
#            FORNECEDOR DOCUMENTO        DATA  \
# 298973  Exceller Tour    WIXHAI  06/12/2022
# 298974  Exceller Tour    WITOLM  09/12/2022
# 298975  Exceller Tour    THPKVQ  20/12/2022
# 298976  Exceller Tour    QNN9HX  21/12/2022
# 298977  Exceller Tour    WMQWBX  30/12/2022
#
#                                              DETALHAMENTO VALOR_REEMBOLSADO  \
# 298973  Companhia Aérea: LATAM, Localizador: WIXHAI. P...           2893,04
# 298974  Companhia Aérea: GOL, Localizador: WITOLM. Pas...           1180,19
# 298975  Companhia Aérea: TAM, Localizador: THPKVQ. Pas...            2671,9
# 298976  Companhia Aérea: AZUL, Localizador: QNN9HX. Pa...           1334,31
# 298977  Companhia Aérea: TAM, Localizador: WMQWBX. Pas...           2250,72
#
#         COD_DOCUMENTO
# 298973      2191398.0
# 298974      2192272.0
# 298975      2192274.0
# 298976      2192244.0
# 298977      2193622.0

# %%
# Verificando dados nulos
dados_ceaps.isnull().sum()
# Out:
# ANO                       0
# MES                       0
# SENADOR                   0
# TIPO_DESPESA              0
# CNPJ_CPF                  0
# FORNECEDOR                0
# DOCUMENTO             20226
# DATA                      0
# DETALHAMENTO         118347
# VALOR_REEMBOLSADO         0
# COD_DOCUMENTO             2
# dtype: int64

# %%
# Identificando duplicatas, houve um erro da importação dos dados nas colunas documento, data, detalhamento, valor_reembolsado e código do documento
dados_ceaps[dados_ceaps['COD_DOCUMENTO'].duplicated(keep = False)]
# Out:
#          ANO  MES         SENADOR  \
# 131284  2015    8  EDUARDO AMORIM
# 131291  2015    8  EDUARDO AMORIM
#
#                                              TIPO_DESPESA            CNPJ_CPF  \
# 131284  Passagens aéreas, aquáticas e terrestres nacio...  13.353.495/0001-84
# 131291  Passagens aéreas, aquáticas e terrestres nacio...  13.353.495/0001-84
#
#                              FORNECEDOR                  DOCUMENTO  \
# 131284  PROPAGTUR - Propag Turismo Ltda    SEM FATURA";02/08/2015"
# 131291  PROPAGTUR - Propag Turismo Ltda  ¨¨SEM FATURA";17/08/2015"
#
#                                                      DATA DETALHAMENTO  \
# 131284  Companhia Aérea: TAM, Localizador: YXGDSJ. Pas...       469,53
# 131291  Companhia Aérea: AVIANCA, Localizador: ZNEU9F....       460,45
#
#        VALOR_REEMBOLSADO  COD_DOCUMENTO
# 131284           2014675            NaN
# 131291           2016557            NaN

# %%
# Reorganizando os registros nas colunas adequadas
duplicado1 = 131284

dados_ceaps.loc[duplicado1, 'COD_DOCUMENTO'] = dados_ceaps.loc[duplicado1, 'VALOR_REEMBOLSADO']
dados_ceaps.loc[duplicado1, 'VALOR_REEMBOLSADO'] = dados_ceaps.loc[duplicado1, 'DETALHAMENTO']
dados_ceaps.loc[duplicado1, 'DETALHAMENTO'] = dados_ceaps.loc[duplicado1, 'DATA']
dados_ceaps.loc[duplicado1, 'DATA'] = '02/08/2015'
dados_ceaps.loc[duplicado1, 'DOCUMENTO'] = 'SEM FATURA'
dados_ceaps.loc[duplicado1, 'VALOR_REEMBOLSADO'] = 469.53

duplicado2 = 131291

dados_ceaps.loc[duplicado2, 'COD_DOCUMENTO'] = dados_ceaps.loc[duplicado2, 'VALOR_REEMBOLSADO']
dados_ceaps.loc[duplicado2, 'VALOR_REEMBOLSADO'] = dados_ceaps.loc[duplicado2, 'DETALHAMENTO']
dados_ceaps.loc[duplicado2, 'DETALHAMENTO'] = dados_ceaps.loc[duplicado2, 'DATA']
dados_ceaps.loc[duplicado2, 'DATA'] = '17/08/2015'
dados_ceaps.loc[duplicado2, 'DOCUMENTO'] = 'SEM FATURA'
dados_ceaps.loc[duplicado2, 'VALOR_REEMBOLSADO'] = 460.45

dados_ceaps.loc[[duplicado1 ,duplicado2]]
# Out:
#          ANO  MES         SENADOR  \
# 131284  2015    8  EDUARDO AMORIM
# 131291  2015    8  EDUARDO AMORIM
#
#                                              TIPO_DESPESA            CNPJ_CPF  \
# 131284  Passagens aéreas, aquáticas e terrestres nacio...  13.353.495/0001-84
# 131291  Passagens aéreas, aquáticas e terrestres nacio...  13.353.495/0001-84
#
#                              FORNECEDOR   DOCUMENTO        DATA  \
# 131284  PROPAGTUR - Propag Turismo Ltda  SEM FATURA  02/08/2015
# 131291  PROPAGTUR - Propag Turismo Ltda  SEM FATURA  17/08/2015
#
#                                              DETALHAMENTO VALOR_REEMBOLSADO  \
# 131284  Companhia Aérea: TAM, Localizador: YXGDSJ. Pas...            469.53
# 131291  Companhia Aérea: AVIANCA, Localizador: ZNEU9F....            460.45
#
#        COD_DOCUMENTO
# 131284       2014675
# 131291       2016557

# %%
# Reconferência de duplicatas
dados_ceaps[dados_ceaps['COD_DOCUMENTO'].duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [ANO, MES, SENADOR, TIPO_DESPESA, CNPJ_CPF, FORNECEDOR, DOCUMENTO, DATA, DETALHAMENTO, VALOR_REEMBOLSADO, COD_DOCUMENTO]
# Index: []

# %%
# Compreendendo composição da coluna detalhamento
dados_ceaps['DETALHAMENTO'].unique()
# Out:
# array([nan,
#        'BILHETE UTILIZADO PELO SENADOR ACIR GURGACZ. TRECHO: BRASÍLIA/ CUIABÁ. TAM-VOO-JJ-3648. DIA22/JUN/2011.',
#        'BILHETE UTILIZADO PELO SENADOR ACIR GURGACZ. TRECHO: PORTO VELHO/BRASÍLIA. TAM-VOO-JJ-3687. DIA-27/JUN/2011.',
#        ...,
#        'Companhia Aérea: TAM, Localizador: THPKVQ. Passageiros: JOSÉ DA CRUZ MARINHO (Matrícula 341141, PARLAMENTAR), Voo: 3608 - BSB/BELÉM - 22/12/2022;',
#        'Companhia Aérea: AZUL, Localizador: QNN9HX. Passageiros: JOSÉ DA CRUZ MARINHO (Matrícula 341141, PARLAMENTAR), Voo: 4112 - BEL/MAB - 23/12/2022;',
#        'Companhia Aérea: TAM, Localizador: WMQWBX. Passageiros: YURI PEREIRA CARNEIRO AGE (Matrícula 300461, COMISSIONADO), Voo: 3608 - BSB/BELÉM - 08/01/2023; YURI PEREIRA CARNEIRO AGE (Matrícula 300461, COMISSIONADO), Voo: 3609 - BELÉM/BSB - 20/01/2023;'],
#       dtype=object)

# %%
# Compreendendo composição da coluna tipo_despesa, concluímos que a coluna detalhamento é mais informativa para análises
dados_ceaps['TIPO_DESPESA'].unique()
# Out:
# array(['Aluguel de imóveis para escritório político, compreendendo despesas concernentes a eles.',
#        'Divulgação da atividade parlamentar',
#        'Locomoção, hospedagem, alimentação, combustíveis e lubrificantes',
#        'Aquisição de material de consumo para uso no escritório político, inclusive aquisição ou locação de software, despesas postais, aquisição de publicações, locação de móveis e de equipamentos. ',
#        'Contratação de consultorias, assessorias, pesquisas, trabalhos técnicos e outros serviços de apoio ao exercício do mandato parlamentar',
#        'Passagens aéreas, aquáticas e terrestres nacionais',
#        'Serviços de Segurança Privada'], dtype=object)

# %%
dados_copia = dados_ceaps.copy # Backup dos dados para evitar exclusões incorretas

dados_ceaps = dados_ceaps.drop(columns = ['DOCUMENTO', 'COD_DOCUMENTO']) # removendo DOCUMENTO E COD_DOCUMENTO

dados_ceaps.loc[dados_ceaps['DETALHAMENTO'].isnull(), 'DETALHAMENTO'] = dados_ceaps[dados_ceaps['DETALHAMENTO'].isnull()]['TIPO_DESPESA'] # preenchendo dados ausentes

# %%
# Reconferência de dados ausentes
dados_ceaps.isnull().sum()
# Out:
# ANO                  0
# MES                  0
# SENADOR              0
# TIPO_DESPESA         0
# CNPJ_CPF             0
# FORNECEDOR           0
# DATA                 0
# DETALHAMENTO         0
# VALOR_REEMBOLSADO    0
# dtype: int64

# %%
# Identificando estruturas de dados do Data Frame
dados_ceaps.dtypes
# Out:
# ANO                   int64
# MES                   int64
# SENADOR              object
# TIPO_DESPESA         object
# CNPJ_CPF             object
# FORNECEDOR           object
# DATA                 object
# DETALHAMENTO         object
# VALOR_REEMBOLSADO    object
# dtype: object

# %%
# Corrigindo formato de dados da coluna ANO para uma possível análise de Time Series
dados_ceaps['ANO'] =  pd.to_datetime(dados_ceaps['ANO'], format='%Y')

# %%
dados_ceaps.dtypes
# Out:
# ANO                  datetime64[ns]
# MES                           int64
# SENADOR                      object
# TIPO_DESPESA                 object
# CNPJ_CPF                     object
# FORNECEDOR                   object
# DATA                         object
# DETALHAMENTO                 object
# VALOR_REEMBOLSADO            object
# dtype: object

# %%
# Correção da notação de valores para conversão do tipo de dados para Float
dados_ceaps['CORREÇÃO_VALORES'] = dados_ceaps['VALOR_REEMBOLSADO'].str.replace(',', '.')

# %%
dados_ceaps.head(10)
# Out:
#          ANO  MES       SENADOR  \
# 0 2010-01-01    1  ACIR GURGACZ
# 1 2010-01-01    1  ACIR GURGACZ
# 2 2010-01-01    1  ACIR GURGACZ
# 3 2010-01-01    1  ACIR GURGACZ
# 4 2010-01-01    1  ACIR GURGACZ
# 5 2010-01-01    1  ACIR GURGACZ
# 6 2010-01-01    1  ACIR GURGACZ
# 7 2010-01-01    1  ACIR GURGACZ
# 8 2010-01-01    2  ACIR GURGACZ
# 9 2010-01-01    2  ACIR GURGACZ
#
#                                         TIPO_DESPESA            CNPJ_CPF  \
# 0  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 1  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 2  Aluguel de imóveis para escritório político, c...      004.948.028-63
# 3                Divulgação da atividade parlamentar  09.040.457/0001-02
# 4  Locomoção, hospedagem, alimentação, combustíve...  15.896.509/0001-31
# 5  Locomoção, hospedagem, alimentação, combustíve...  15.896.509/0001-31
# 6  Locomoção, hospedagem, alimentação, combustíve...  63.755.391/0001-74
# 7  Locomoção, hospedagem, alimentação, combustíve...  63.755.391/0001-74
# 8  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 9  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
#
#                                FORNECEDOR        DATA  \
# 0          CENTRAIS ELÉTRICAS DE RONDÔNIA  19/01/2010
# 1          CENTRAIS ELÉTRICAS DE RONDônia  19/01/2010
# 2           GILBERTO PISELO DO NASCIMENTO  12/01/2010
# 3                    CENTRAL RONDÔNIA.COM  05/01/2010
# 4                         POSTO FORTALEZA  07/01/2010
# 5                         POSTO FORTALEZA  27/01/2010
# 6                  VICENTE & TESTONI LTDA  07/01/2010
# 7                  vicente & testoni ltda  02/01/2010
# 8  CENTRAIS ELÉTRICAS DE RONDÔNIA - CERON  19/02/2010
# 9  CENTRAIS ELÉTRICAS DE RONDÔNIA - CERON  19/02/2010
#
#                                         DETALHAMENTO VALOR_REEMBOLSADO  \
# 0  Aluguel de imóveis para escritório político, c...             59,08
# 1  Aluguel de imóveis para escritório político, c...             40,47
# 2  Aluguel de imóveis para escritório político, c...              5000
# 3                Divulgação da atividade parlamentar              1500
# 4  Locomoção, hospedagem, alimentação, combustíve...                30
# 5  Locomoção, hospedagem, alimentação, combustíve...               111
# 6  Locomoção, hospedagem, alimentação, combustíve...               100
# 7  Locomoção, hospedagem, alimentação, combustíve...                50
# 8  Aluguel de imóveis para escritório político, c...             40,27
# 9  Aluguel de imóveis para escritório político, c...             69,27
#
#   CORREÇÃO_VALORES
# 0            59.08
# 1            40.47
# 2             5000
# 3             1500
# 4               30
# 5              111
# 6              100
# 7               50
# 8            40.27
# 9            69.27

# %%
# Corrigindo demais valores errôneos
dados_ceaps['CORREÇÃO_VALORES'] = dados_ceaps['CORREÇÃO_VALORES'].str.replace('1\r\n675.55', '1675.55')
dados_ceaps.head()
# Out:
# <ipython-input-106-cf7e5e21bb2b>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   dados_ceaps['CORREÇÃO_VALORES'] = dados_ceaps['CORREÇÃO_VALORES'].str.replace('1\r\n675.55', '1675.55')
#          ANO  MES       SENADOR  \
# 0 2010-01-01    1  ACIR GURGACZ
# 1 2010-01-01    1  ACIR GURGACZ
# 2 2010-01-01    1  ACIR GURGACZ
# 3 2010-01-01    1  ACIR GURGACZ
# 4 2010-01-01    1  ACIR GURGACZ
#
#                                         TIPO_DESPESA            CNPJ_CPF  \
# 0  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 1  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 2  Aluguel de imóveis para escritório político, c...      004.948.028-63
# 3                Divulgação da atividade parlamentar  09.040.457/0001-02
# 4  Locomoção, hospedagem, alimentação, combustíve...  15.896.509/0001-31
#
#                        FORNECEDOR        DATA  \
# 0  CENTRAIS ELÉTRICAS DE RONDÔNIA  19/01/2010
# 1  CENTRAIS ELÉTRICAS DE RONDônia  19/01/2010
# 2   GILBERTO PISELO DO NASCIMENTO  12/01/2010
# 3            CENTRAL RONDÔNIA.COM  05/01/2010
# 4                 POSTO FORTALEZA  07/01/2010
#
#                                         DETALHAMENTO VALOR_REEMBOLSADO  \
# 0  Aluguel de imóveis para escritório político, c...             59,08
# 1  Aluguel de imóveis para escritório político, c...             40,47
# 2  Aluguel de imóveis para escritório político, c...              5000
# 3                Divulgação da atividade parlamentar              1500
# 4  Locomoção, hospedagem, alimentação, combustíve...                30
#
#   CORREÇÃO_VALORES
# 0            59.08
# 1            40.47
# 2             5000
# 3             1500
# 4               30

# %%
# Conversão para float
dados_ceaps['CORREÇÃO_VALORES'] = dados_ceaps['CORREÇÃO_VALORES'].astype(float)
dados_ceaps.head()
# Out:
#          ANO  MES       SENADOR  \
# 0 2010-01-01    1  ACIR GURGACZ
# 1 2010-01-01    1  ACIR GURGACZ
# 2 2010-01-01    1  ACIR GURGACZ
# 3 2010-01-01    1  ACIR GURGACZ
# 4 2010-01-01    1  ACIR GURGACZ
#
#                                         TIPO_DESPESA            CNPJ_CPF  \
# 0  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 1  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 2  Aluguel de imóveis para escritório político, c...      004.948.028-63
# 3                Divulgação da atividade parlamentar  09.040.457/0001-02
# 4  Locomoção, hospedagem, alimentação, combustíve...  15.896.509/0001-31
#
#                        FORNECEDOR        DATA  \
# 0  CENTRAIS ELÉTRICAS DE RONDÔNIA  19/01/2010
# 1  CENTRAIS ELÉTRICAS DE RONDônia  19/01/2010
# 2   GILBERTO PISELO DO NASCIMENTO  12/01/2010
# 3            CENTRAL RONDÔNIA.COM  05/01/2010
# 4                 POSTO FORTALEZA  07/01/2010
#
#                                         DETALHAMENTO VALOR_REEMBOLSADO  \
# 0  Aluguel de imóveis para escritório político, c...             59,08
# 1  Aluguel de imóveis para escritório político, c...             40,47
# 2  Aluguel de imóveis para escritório político, c...              5000
# 3                Divulgação da atividade parlamentar              1500
# 4  Locomoção, hospedagem, alimentação, combustíve...                30
#
#    CORREÇÃO_VALORES
# 0             59.08
# 1             40.47
# 2           5000.00
# 3           1500.00
# 4             30.00

# %%
# Substituição da coluna Valor_Reembolsado
dados_ceaps['VALOR_REEMBOLSADO'] = dados_ceaps['CORREÇÃO_VALORES']
dados_ceaps.head()
# Out:
#          ANO  MES       SENADOR  \
# 0 2010-01-01    1  ACIR GURGACZ
# 1 2010-01-01    1  ACIR GURGACZ
# 2 2010-01-01    1  ACIR GURGACZ
# 3 2010-01-01    1  ACIR GURGACZ
# 4 2010-01-01    1  ACIR GURGACZ
#
#                                         TIPO_DESPESA            CNPJ_CPF  \
# 0  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 1  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 2  Aluguel de imóveis para escritório político, c...      004.948.028-63
# 3                Divulgação da atividade parlamentar  09.040.457/0001-02
# 4  Locomoção, hospedagem, alimentação, combustíve...  15.896.509/0001-31
#
#                        FORNECEDOR        DATA  \
# 0  CENTRAIS ELÉTRICAS DE RONDÔNIA  19/01/2010
# 1  CENTRAIS ELÉTRICAS DE RONDônia  19/01/2010
# 2   GILBERTO PISELO DO NASCIMENTO  12/01/2010
# 3            CENTRAL RONDÔNIA.COM  05/01/2010
# 4                 POSTO FORTALEZA  07/01/2010
#
#                                         DETALHAMENTO  VALOR_REEMBOLSADO  \
# 0  Aluguel de imóveis para escritório político, c...              59.08
# 1  Aluguel de imóveis para escritório político, c...              40.47
# 2  Aluguel de imóveis para escritório político, c...            5000.00
# 3                Divulgação da atividade parlamentar            1500.00
# 4  Locomoção, hospedagem, alimentação, combustíve...              30.00
#
#    CORREÇÃO_VALORES
# 0             59.08
# 1             40.47
# 2           5000.00
# 3           1500.00
# 4             30.00

# %%
# Exclusão da coluna de correção
dados_ceaps = dados_ceaps.drop(columns = ['CORREÇÃO_VALORES'])
dados_ceaps.head()
# Out:
#          ANO  MES       SENADOR  \
# 0 2010-01-01    1  ACIR GURGACZ
# 1 2010-01-01    1  ACIR GURGACZ
# 2 2010-01-01    1  ACIR GURGACZ
# 3 2010-01-01    1  ACIR GURGACZ
# 4 2010-01-01    1  ACIR GURGACZ
#
#                                         TIPO_DESPESA            CNPJ_CPF  \
# 0  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 1  Aluguel de imóveis para escritório político, c...  05.914.650/0001-66
# 2  Aluguel de imóveis para escritório político, c...      004.948.028-63
# 3                Divulgação da atividade parlamentar  09.040.457/0001-02
# 4  Locomoção, hospedagem, alimentação, combustíve...  15.896.509/0001-31
#
#                        FORNECEDOR        DATA  \
# 0  CENTRAIS ELÉTRICAS DE RONDÔNIA  19/01/2010
# 1  CENTRAIS ELÉTRICAS DE RONDônia  19/01/2010
# 2   GILBERTO PISELO DO NASCIMENTO  12/01/2010
# 3            CENTRAL RONDÔNIA.COM  05/01/2010
# 4                 POSTO FORTALEZA  07/01/2010
#
#                                         DETALHAMENTO  VALOR_REEMBOLSADO
# 0  Aluguel de imóveis para escritório político, c...              59.08
# 1  Aluguel de imóveis para escritório político, c...              40.47
# 2  Aluguel de imóveis para escritório político, c...            5000.00
# 3                Divulgação da atividade parlamentar            1500.00
# 4  Locomoção, hospedagem, alimentação, combustíve...              30.00

# %%
# Reconferência da estrutura de dados do Data Frame
dados_ceaps.dtypes
# Out:
# ANO                  datetime64[ns]
# MES                           int64
# SENADOR                      object
# TIPO_DESPESA                 object
# CNPJ_CPF                     object
# FORNECEDOR                   object
# DATA                         object
# DETALHAMENTO                 object
# VALOR_REEMBOLSADO           float64
# dtype: object

# %%
# Conferência das estatísticas básicas do Data Frame, como temos um valor mínimo negativo, podemos concluir que há valores negativos no nosso Data Frame. Estes dados não condizem com a coluna Valor_Reembolsado
dados_ceaps.describe()
# Out:
#                  MES  VALOR_REEMBOLSADO
# count  298978.000000      298976.000000
# mean        6.580033        1005.558869
# std         3.322765        2578.843393
# min         1.000000       -1500.000000
# 25%         4.000000         100.020000
# 50%         7.000000         296.530000
# 75%         9.000000        1000.000000
# max        12.000000      270000.000000

# %%
# Identificando valores negativos do Data Frame
dados_ceaps.query('VALOR_REEMBOLSADO <-1')
# Out:
#               ANO  MES             SENADOR  \
# 133386 2015-01-01    2      GLADSON CAMELI
# 144296 2015-01-01    1  RANDOLFE RODRIGUES
# 182570 2017-01-01    5        DÁRIO BERGER
#
#                                              TIPO_DESPESA            CNPJ_CPF  \
# 133386  Aluguel de imóveis para escritório político, c...  63.600.449/0001-00
# 144296  Passagens aéreas, aquáticas e terrestres nacio...  02.012.862/0001-60
# 182570  Contratação de consultorias, assessorias, pesq...  73.228.876/0001-63
#
#                                                FORNECEDOR        DATA  \
# 133386  Arras Adm. de Bens Imóveis Limpeza e Conservaç...  15/01/2015
# 144296                              Tam Linhas Aereas S/A  28/01/2015
# 182570                             TV CLIPAGEM LTDA. EPP.  02/06/2017
#
#                                              DETALHAMENTO  VALOR_REEMBOLSADO
# 133386  Contrato de locação de Imóvel comercial do esc...            -1500.0
# 144296  9572100929351 - R$ 1.298,93 (1º bilhete emitid...               -9.0
# 182570  Despesa com Monitoramento de Informação Jornal...             -243.4

# %%
# O primeiro valor foi apenas um erro de digitação, podemos apenas converter para o valor do módulo
dados_ceaps.loc[133386	, 'VALOR_REEMBOLSADO'] = dados_ceaps.loc[133386	, 'VALOR_REEMBOLSADO']* -1
dados_ceaps.loc[133386	, 'VALOR_REEMBOLSADO']
# Out:
# 1500.0

# %%
# Como o segundo valor é muito pequeno em módulo, vamos consultar o detalhamento para verificar se o valor é condizente com a despesa
dados_ceaps.loc[144296, 'DETALHAMENTO']
# Out:
# '9572100929351 - R$ 1.298,93 (1º bilhete emitido) 9572102224403 - R$ 1.418,93 (1ª remarcação) 9572104023443 - R$ 1.498,93 (2ª remarcação) 9572104373256 - R$ 2.412,03 (3ª remarcação - bilhete utilizado)'

# %%
# Como o detalhamento nos informa que o terceiro bilhete foi o utilizado, devemos atualizar o valor reembolsado com ele
dados_ceaps.loc[144296, 'VALOR_REEMBOLSADO'] = 2412.03
dados_ceaps.loc[144296, 'VALOR_REEMBOLSADO']
# Out:
# 2412.03

# %%
# Realizando a mesma conferência para o terceiro valor, como este é condizente com o valor absoluto de uma despesa com esta classificação também podemos considerar o seu módulo para análises
dados_ceaps.loc[182570, 'DETALHAMENTO']
# Out:
# 'Despesa com Monitoramento de Informação Jornalística em Mídia Eletrônica e Imprensa'

# %%
# Correção do valor
dados_ceaps.loc[182570, 'VALOR_REEMBOLSADO'] = 243.40
dados_ceaps.loc[182570, 'VALOR_REEMBOLSADO']
# Out:
# 243.4

# %%
# Excluindo colunas que não são necessárias para nossas análises
dados_ceaps.drop(columns = ['DATA', 'MES'], inplace = True)

# %%
# Exportação dos dados para construção de visualizações futuras
dados_ceaps.to_csv('dados_2010_2022.csv', sep=';', index = False)
